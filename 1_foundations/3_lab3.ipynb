# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contactar
# ezebinker@gmail.com
# www.linkedin.com/in/
# ezequielbinker (LinkedIn)
# Aptitudes principales
# Go
# Infraestructura de software
# Ingeniería
# Languages
# Inglés (Full Professional)
# Español (Native or Bilingual)
# Certifications
# Productividad Personal en la Era
# Digital
# People Leadership Credential –
# Chapter 1: Connect
# Modelado de Sistemas Orientados a
# Objetos con Rational
# Cloud Computing Fundamentals
# Honors-Awards
# Graduación con honores
# Curso de Coordinación - Nofim
# Ezequiel Binker
# Web Development Lead @Accenture
# Argentina
# Extracto
# Soy Licenciado en Sistemas recibido en Universidad de Palermo.
# Emprendo proyectos de manera freelance desde 2019. Cuento con
# experiencia en el mercado, como desarrollador backend para un
# banco canadiense y como desarrollador full stack y líder técnico
# para una consultora mexicana. Hace más de 10 años trabajo en
# educación tecnológica, transmitiendo los conceptos y buenas
# prácticas de programación a cientos de jóvenes de nivel secundario
# y terciario.
# Actualmente, soy Web Development Lead en Accenture, donde
# lidero un equipo de desarrolladores full stack en el equipo de Data
# Analytics & Storytelling.
# Mis conocimientos en educación y experiencia en liderazgo me
# permiten comunicar mis pensamientos e intenciones de una manera
# clara y eficiente.
# Quedamos en contacto  ezebinker@gmail.com !
# Experiencia
# Accenture
# Analytics and Modeling Associate Manager
# noviembre de 2024 - Present (1 año 2 meses)
# Argentina
# Soy líder de un equipo de desarrolladores full stack en el área de Data
# Analytics & Storytelling, parte de Accenture One Finance. Desde este
# rol, impulsamos la construcción de productos digitales que aceleran la
# transformación digital y optimizan las herramientas de trabajo de nuestros
# clientes. Nuestro stack incluye React, con compilación mediante Vite, y
# Node.js para el desarrollo web, utilizando TypeScript como lenguaje principal y
# gestionando nuestros repositorios de código a través de Azure DevOps.
#   Page 1 of 6
# Además de liderar técnicamente el desarrollo, estoy a cargo de la
# coordinación de un equipo de tres desarrolladores web, con asignación a
# más de diez proyectos en simultáneo. Defino estándares técnicos, promuevo
# el uso de metodologías ágiles y mejores prácticas de desarrollo, y priorizo
# la escalabilidad y la eficiencia de las soluciones. Fomento la colaboración
# interdisciplinaria y el crecimiento técnico del equipo, creando un entorno de
# aprendizaje continuo.
# Durante este período, hemos logrado mejorar significativamente la velocidad
# de entrega de valor en los diferentes productos y construir un equipo de
# desarrollo robusto y multidisciplinario, capaz de enfrentar desafíos complejos y
# entregar resultados de alto impacto.
# ORT Argentina
# 11 años 7 meses
# Profesor
# marzo de 2016 - Present (9 años 10 meses)
# Mi experiencia docente en ORT Argentina ha sido diversa y enriquecedora,
# cubriendo varias áreas clave de la educación informática. Actualmente me
# encuentro trabajando en Taller de Programación de 4to año, donde enseño
# C#, programación orientada a objetos, maquetado web con HTML, CSS,
# Bootstrap, y desarrollo MVC en .NET Core. Incluyo conexión a bases de datos
# con Dapper ORM y dinámicas con JavaScript y AJAX.
# Coordino además académicamente las materias de 4to año de la
# especialidad. En este rol pude colaborar con el director de la orientación en
# mejorar los planes educativos, las propuestas pedagógicas en el aula, y los
# eventos de difusión y de producción de proyectos de nuestros estudiantes,
# como por ejemplo INFO 360. Guiados por tutores y facilitadores nuestros
# estudiantes trabajan de forma integral en las 5 materias de Informática en
# la elaboración de un proyecto desde 0 aplicando todos los conocimientos
# adquiridos.
# En el pasado participé en los equipos de materia de las siguientes
# asignaturas:
# Proyectos de Producción (5to año): Pude guiar a estudiantes en la integración
# de conocimientos en un proyecto final, destacando buenas prácticas, trabajo
# en equipo, y metodologías ágiles.
#   Page 2 of 6
# Diseño Web (4to año): Foco en UX/UI, usando HTML, CSS, y Design Thinking
# para crear productos digitales centrados en el usuario.
# Bases de Datos (4to año): Desarrollo y administración de bases de datos
# relacionales (principalmente SQL Server y MySQL) como así también
# exploración de NoSQL y fundamentos de ciencia de datos.
# Además, durante dos años dicté clases en el Instituto Tecnológico ORT
# de nivel terciario, abordando algoritmos en Java y compartiendo mis
# conocimientos en programación orientada a objetos.
# Asistente de Laboratorio de Informática
# junio de 2014 - febrero de 2022 (7 años 9 meses)
# Mis responsabilidades incluyeron la gestión de proyectos internos, brindar
# asistencia a estudiantes de secundaria en el desarrollo de aplicaciones en
# lenguajes como C#, Java, SQL y JavaScript, seguimiento y apoyo en sus
# Proyectos Finales, investigar y desarrollar tecnologías para mejorar procesos
# y proyectos, y mantener y cuidar los recursos de los laboratorios informáticos.
# REXX Studio, Inc.
# Desarrollador full stack
# mayo de 2024 - noviembre de 2024 (7 meses)
# Ciudad de México, México
# Desarrollador Full Stack con experiencia en Electron (JavaScript), Node, ejs,
# Laravel (PHP) y Angular.
# Mis aportes activos en el código fuente fueron principalmente en un
# proyecto para una importante empresa de industria textil, y un sistema de
# administración de proyectos edilicios.
# También fui responsable de decisiones arquitectónicas para nuevos
# proyectos, coaching a miembros del equipo en diferentes tópicos, entrevistas
# y pruebas técnicas a posibles ingresantes a la empresa y revisiones de código
# a desarrolladores del equipo.
# Logré mejoras en la gestión de proyectos usando GitHub y Slack, así como en
# la documentación de código y diseño con Google Drive y Notion.
# Además, he trabajado con herramientas de integración y entrega continua
# como Jenkins
#   Page 3 of 6
# Profesional independiente
# Desarrollador Full Stack
# enero de 2019 - noviembre de 2024 (5 años 11 meses)
# He adquirido experiencia en proyectos personales, tanto en el desarrollo
# Frontend utilizando tecnologías como HTML, CSS, y React.js, como en el
# desarrollo Backend empleando TypeScript, Node.js y Nest.js. Además, he
# incursionado en el desarrollo móvil utilizando React Native.
# Mis habilidades destacadas se centran en el uso de NestJS y TypeScript,
# áreas en las que he acumulado experiencia significativa a lo largo de mi
# trayectoria profesional.
# Wadiah Capital
# Desarrollador Backend
# noviembre de 2021 - noviembre de 2023 (2 años 1 mes)
# Canadá
# Trabajé durante dos años en el rediseño funcional del sistema informático de
# Wadiah Capital. Comencé a cargo de un módulo que realiza una integración
# con servicios crypto, para luego quedar a cargo del core bancario.
# El stack de backend utilizado está comprendido por Nest.js (Express)
# conectado a una base de datos SQL Server. Además, otras herramientas
# utilizadas durante mi trabajo día a día son : Redis, CircleCI, Docker, Sentry y
# Azure.
# Dentro de mis tareas de I+D realicé algunos proyectos crypto, en los cuales
# puse en práctica conocimientos de Solidity, Pinata Cloud y OpenSea
# Centro Hebreo Ioná
# 6 años 4 meses
# Coordinador
# enero de 2016 - diciembre de 2017 (2 años)
# 4° a 7° grado
# Durante dos años, trabajé como Coordinador en el área de 4° a 7° grado.
# Mi labor consistía en supervisar actividades educativas informales para
# chicos de 8 a 12 años. Me encargaba de liderar equipos, asegurando el
# buen funcionamiento de las actividades, y también capacitaba a líderes de la
# comunidad para que pudieran involucrarse activamente en este proceso.
# Líder de grupos (Madrij)
#   Page 4 of 6
# septiembre de 2011 - diciembre de 2015 (4 años 4 meses)
# En este rol, me encargué de planificar y llevar a cabo actividades de
# educación no formal para jóvenes de edades comprendidas entre los 4 y
# 16 años. Asimismo, estuve involucrado en el desarrollo y la ejecución de
# proyectos institucionales, la generación de material y contenido educativo,
# y la elaboración de presupuestos y planes organizativos para eventos
# comunitarios.
# Cider S.A.
# Técnico
# abril de 2015 - abril de 2015 (1 mes)
# Formé parte del equipo de capacitación del sistema de Boleta Única
# Electrónica durante las elecciones presidenciales PASO del 26 de abril.
# Mis responsabilidades incluyeron la instalación de máquinas, brindar apoyo
# técnico durante la jornada electoral, manejar la logística y encargarme del
# envío de datos al centro de cómputo, entre otras.
# Confort Integral S.A.
# Administrativo
# marzo de 2013 - junio de 2014 (1 año 4 meses)
# Mis responsabilidades incluyeron el control de inventario, supervisión de
# precios, gestión de clientes y créditos, así como desempeñar el rol de
# moderador en la página web de la empresa.
# Educación
# Universidad de Palermo
# Licenciatura en Sistemas, Tecnología de la información · (2018 - 2020)
# Universidad de Palermo
# Programa Ejecutivo Desarrollo con Blockchains, Tecnología de la
# información · (agosto de 2021 - diciembre de 2021)
# Coderhouse
# Diseño UX/UI, Tecnología de la información · (noviembre de 2020 - enero de
# 2021)
# ORT Argentina
# Analista de Sistemas, Tecnología de la información · (2013 - 2017)
#   Page 5 of 6
# ORT Argentina
# Bachiller técnico, Informática y Medios de Comunicación
# Digitales · (2007 - 2012)
#   Page 6 of 6

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Ezequiel Binker"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Ezequiel Binker. You are answering questions on Ezequiel Binker's website, particularly questions related to Ezequiel Binker's career, background, skills and experience. Your responsibility is to represent Ezequiel Binker for interactions on the website as faithfully as possible. You are given a summary of Ezequiel Binker's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ezequiel Binker. I'm a software engineer, with skills in Python, JavaScript, and React. I'm currently learning about AI and machine learning.\nI work in Accenture as Web Development Lead in Buenos Aires, Argentina.\nI'm a quick learner and I'm always looking for new challenges and opportunities to grow. I'm also a team player and I'm always looking for new ways to improve my skills and my team.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContactar\nezebinker@gmail.com\nwww.linkedin.com/in/\nezequielbinker (LinkedIn)\nAptitudes principales\nGo\nInfraestructura de software\nIngeniería\nLanguages\nInglés (Full Professional)\nEspañol (Native or Bilingual)\nCertifications\nProductividad Personal en la Era\nDigital\nPeople Leadership Credential –\nChapter 1: Connect\nModelado de Sistemas Orientados a\nObjetos con Rational\nCloud Computing Fundamentals\nHonors-Awards\nGraduación con honores\nCurso de Coordinación - Nofim\nEzequiel Binker\nWeb Development Lead @Accenture\nArgentina\nExtracto\nSoy Licenciado en Sistemas recibido en Universidad de Palermo.\nEmprendo proyectos de manera freelance desde 2019. Cuento con\nexperiencia en el mercado, como desarrollador backend para un\nbanco canadiense y como desarrollador full stack y líder técnico\npara una consultora mexicana. Hace más de 10 años trabajo en\neducación tecnológica, transmitiendo los conceptos y buenas\nprácticas de programación a cientos de jóvenes de nivel secundario\ny terciario. \nActualmente, soy Web Development Lead en Accenture, donde\nlidero un equipo de desarrolladores full stack en el equipo de Data\nAnalytics & Storytelling.\nMis conocimientos en educación y experiencia en liderazgo me\npermiten comunicar mis pensamientos e intenciones de una manera\nclara y eficiente.\nQuedamos en contacto  ezebinker@gmail.com !\nExperiencia\nAccenture\nAnalytics and Modeling Associate Manager\nnoviembre de 2024\xa0-\xa0Present\xa0(1 año 2 meses)\nArgentina\nSoy líder de un equipo de desarrolladores full stack en el área de Data\nAnalytics & Storytelling, parte de Accenture One Finance. Desde este\nrol, impulsamos la construcción de productos digitales que aceleran la\ntransformación digital y optimizan las herramientas de trabajo de nuestros\nclientes. Nuestro stack incluye React, con compilación mediante Vite, y\nNode.js para el desarrollo web, utilizando TypeScript como lenguaje principal y\ngestionando nuestros repositorios de código a través de Azure DevOps.\n\xa0 Page 1 of 6\xa0 \xa0\nAdemás de liderar técnicamente el desarrollo, estoy a cargo de la\ncoordinación de un equipo de tres desarrolladores web, con asignación a\nmás de diez proyectos en simultáneo. Defino estándares técnicos, promuevo\nel uso de metodologías ágiles y mejores prácticas de desarrollo, y priorizo\nla escalabilidad y la eficiencia de las soluciones. Fomento la colaboración\ninterdisciplinaria y el crecimiento técnico del equipo, creando un entorno de\naprendizaje continuo.\nDurante este período, hemos logrado mejorar significativamente la velocidad\nde entrega de valor en los diferentes productos y construir un equipo de\ndesarrollo robusto y multidisciplinario, capaz de enfrentar desafíos complejos y\nentregar resultados de alto impacto.\nORT Argentina\n11 años 7 meses\nProfesor\nmarzo de 2016\xa0-\xa0Present\xa0(9 años 10 meses)\nMi experiencia docente en ORT Argentina ha sido diversa y enriquecedora,\ncubriendo varias áre ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
from openai import OpenAI

groq = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"), 
    base_url="https://api.groq.com/openai/v1"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = groq.beta.chat.completions.parse(model="openai/gpt-oss-20b", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I currently do not hold any patents. My focus has been primarily on software development and education rather than on patenting inventions. If you have any specific questions about my work or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The response accurately addresses the question, is concise, professional, and invites further discussion. It aligns with the provided background and meets the role expectations.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The response is not acceptable. It is written in pig‑Latin gibberish, which is informal and confusing, and it does not provide a clear answer to the question about having a patent. A professional reply should be concise, written in standard Spanish or English, and explicitly state whether you have a patent or not. It should also maintain the engaging tone expected from Ezequiel Binker’s website persona.
